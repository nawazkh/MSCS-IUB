# %%
import matplotlib.pyplot as plt
from scipy.io import wavfile # get the api
from scipy.fftpack import fft
from pylab import *

def f(filename):
    fs, data = wavfile.read(filename) # load the data
#     print type(data), data.shape
#     print 'data: ', data
    a = data # this is a two channel soundtrack, I get the first track
    b=[(ele/2**8.)*2-1 for ele in a] # this is 8-bit track, b is now normalized on [-1,1)
    c = fft(b) # create a list of complex number
    d = len(c)/2  # you only need half of the fft list
    absfft = abs(c[:(d-1)])
    plt.plot(absfft,'r')
#     plt.xlim(xmax=100000)
    plt.show()

# %%
import glob

truck_dir = '/home/subhojit/temp/truck-audioset/trucks/'

for wf in glob.glob(truck_dir+'*.wav'):
    print wf
    f(wf)
# Out:
# /home/subhojit/temp/truck-audioset/trucks/1PM96hV5XMo.wav
# /home/subhojit/temp/truck-audioset/trucks/5perV0v6lkk.wav
# /home/subhojit/temp/truck-audioset/trucks/-2PDE7hUArE.wav
# /home/subhojit/temp/truck-audioset/trucks/0XnlJAdG5e8.wav
# /home/subhojit/temp/truck-audioset/trucks/0yZgsUq3yWY.wav
# /home/subhojit/temp/truck-audioset/trucks/-DNkAalo7og.wav
# /home/subhojit/temp/truck-audioset/trucks/5ftfKerE6s0.wav
# /home/subhojit/temp/truck-audioset/trucks/0XrVauCq9JU.wav
# /home/subhojit/temp/truck-audioset/trucks/0ix_rHxU54w.wav
# /home/subhojit/temp/truck-audioset/trucks/3AYBZ2623dk.wav
